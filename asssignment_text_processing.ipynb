# %%
import pandas as pd
import re
import string

# %%
df= pd.read_csv('./movies.csv', index_col=False)

# %%
df.head()
# Out:
#                       title  \
# 0  The Shawshank Redemption
# 1             The Godfather
# 2     The Godfather Part II
# 3          Schindler's List
# 4              12 Angry Men
#
#                                          description               genres
# 0  Imprisoned in the 1940s for the double murder ...         Drama, Crime
# 1  The story of the Corleone crime family as Mich...         Drama, Crime
# 2  Parallel stories of young Vito Corleone’s rise...         Drama, Crime
# 3  The true story of Oskar Schindler, who saved o...  Drama, History, War
# 4  Twelve jurors deliberate the fate of a young m...                Drama

# %%
df.columns
# Out:
# Index(['title', 'description', 'genres'], dtype='object')

# %%
def clean_text(text):
    if pd.isna(text):  # handle missing values
        return ""
    text = text.strip()  # remove leading/trailing spaces
    text = re.sub(r'\s+', ' ', text)  # replace multiple spaces with single space
    text = text.lower()
    text = re.sub(r'[^a-zA-Z0-9\s,.!?]', '', text) 
    text = text.translate(str.maketrans('', '', string.punctuation))
    return text

df['title'] = df['title'].apply(clean_text)
df['description'] = df['description'].apply(clean_text)
df['genres'] = df['genres'].apply(clean_text)

df.to_csv("movies_cleaned.csv", index=False)

print("CSV cleaned (punctuation removed) and saved as movies_cleaned.csv")
# Out:
# CSV cleaned (punctuation removed) and saved as movies_cleaned.csv

# %%
df = pd.read_csv('./movies_cleaned.csv')

# %%
df.head()
# Out:
#                       title  \
# 0  the shawshank redemption
# 1             the godfather
# 2     the godfather part ii
# 3           schindlers list
# 4              12 angry men
#
#                                          description             genres
# 0  imprisoned in the 1940s for the double murder ...        drama crime
# 1  the story of the corleone crime family as mich...        drama crime
# 2  parallel stories of young vito corleones rise ...        drama crime
# 3  the true story of oskar schindler who saved ov...  drama history war
# 4  twelve jurors deliberate the fate of a young m...              drama
